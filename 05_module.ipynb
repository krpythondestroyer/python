# %% [markdown]
# ## 모듈

# %%
import fact

# %%
print(fact)
# Out:
# <module 'fact' from 'C:\\Users\\이아랑\\Desktop\\DMF\\python\\fact.py'>

# %%
print(fact.factorial(5))
# Out:
# 120

# %%
print(fact.my_max(2,4))
# Out:
# 4

# %%
dir(fact)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'factorial',
#  'my_max',
#  'my_number']

# %% [markdown]
# # 패키지
#
# ```
# 마이패키지/
#     이니트
#     매스/
#         이니트.
#
# ```
#     패키지 안에 "이니파이" 파일이 존재해야만 패키지로 인식( 모든 폴더마다)

# %%
import myPackage

# %%
from myPackage import math

# %%
print(myPackage)
# Out:
# <module 'myPackage' from 'C:\\Users\\이아랑\\Desktop\\DMF\\python\\myPackage\\__init__.py'>

# %%
import myPackage

# %%
from myPackage.math import fomula

# %%
fomula.my_max(1, 2)
# Out:
# 2

# %%
fomula.pi
# Out:
# 3.14

# %%
from myPackage.math.fomula import my_max, fact, pi 
print(my_max(1,2))
print(pi)
# Out:
# 2
# 3.14

# %%
from myPackage.math.fomula import *
print(pi)
# Out:
# 3.14

# %%
fomula = 1234
print(fomula)
from myPackage.math import fomula as f
print(fomula)
print(f)
# Out:
# 1234
# 1234
# <module 'myPackage.math.fomula' from 'C:\\Users\\이아랑\\Desktop\\DMF\\python\\myPackage\\math\\fomula.py'>

# %% [markdown]
# ## 파이썬 내장 패키지

# %% [markdown]
# ## math

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e

# %%
math.ceil(math.pi)

# %%
math.floor(math.pi)

# %%
math.sqrt(9)

# %%
math.fac

# %% [markdown]
# ## random

# %%
import random

# %%
random.random()
# Out:
# 0.8474337369372327

# %%
random.randint(1,10)
# Out:
# 2

# %%
random.seed(123)
random.random()
# Out:
# 0.052363598850944326

# %%
numbers = [1,2,3,4,5]
random.shuffle(numbers)
print(numbers)
# Out:
# [4, 1, 2, 3, 5]

# %%
print(random.choice(numbers))
print(random.choice(numbers))

#복원 추출
# Out:
# 3
# 5

# %%
print(random.sample(numbers,2))
print(random.sample(numbers,2))
# Out:
# [1, 2]
# [5, 4]

# %% [markdown]
# ## datetime

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 7, 2, 10, 45, 11, 362805)

# %%
datetime.today()
# Out:
# datetime.datetime(2024, 7, 2, 10, 45, 23, 233124)

# %%
datetime.utcnow()
# Out:
# C:\Users\이아랑\AppData\Local\Temp\ipykernel_13024\3983769260.py:1: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   datetime.utcnow()
# datetime.datetime(2024, 7, 2, 1, 54, 8, 271344)

# %%
now = datetime.now()
print(now)
now.strftime('%Y년 %m월 %d일 %a')
# Out:
# 2024-07-02 11:02:10.613601
# '2024년 07월 02일 Tue'

# %%
## 공백 채우기

# %%
now.weekday()
# Out:
# 1

# %%
christmas = datetime(2024,12,25)
print(christmas)
# Out:
# 2024-12-25 00:00:00

# %%
from datetime import timedelta

# %%
future = timedelta(days=3)
print(future)
# Out:
# 3 days, 0:00:00

# %%
print (christmas + future)
# Out:
# 2024-12-28 00:00:00

# %%
newyear = datetime(2025,1,1)
now = datetime.now()

print(newyear - now)
# Out:
# 182 days, 12:53:57.086966

# %%
now = datetime.now()
d100 = timedelta(days=100)

print(now + d100)
# Out:
# 2024-10-10 11:06:40.792378

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 7, 2, 11, 7, 43, 289800)

# %% [markdown]
# ## 라이브러리

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')
print(r.text)
# Out:
# [{"id":"39785531639","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":443801098,"name":"factcheckr/daum_factcheck","url":"https://api.github.com/repos/factcheckr/daum_factcheck"},"payload":{"repository_id":443801098,"push_id":19131669365,"size":1,"distinct_size":1,"ref":"refs/heads/gh-pages","head":"c2f66ec7a3558dbff1b66948d81d1c9d264c1c31","before":"746c145c6565bba017a3af2c064c2d592313b126","commits":[{"sha":"c2f66ec7a3558dbff1b66948d81d1c9d264c1c31","author":{"email":"amblerkr@users.noreply.github.com","name":"amblerkr"},"message":"Deploying to GitHub Pages from 89cee34520f5195ba6067da708619b25081a901f","distinct":true,"url":"https://api.github.com/repos/factcheckr/daum_factcheck/commits/c2f66ec7a3558dbff1b66948d81d1c9d264c1c31"}]},"public":true,"created_at":"2024-07-02T02:37:
# ...

# %%
payload = {'query': '동아일보'}
r = requests.get('https://search.naver.com/search.naver', params=payload)
print(r.text)
# Out:
# <!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta property="og:title" content="동아일보 : 네이버 검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'동아일보'의 네이버 검색 결과입니다."> <meta name="description" lang="ko" content="'동아일보'의 네이버 검색 결과입니다."> <title>동아일보 : 네이버 검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_240620.css"> <link rel="stylesheet" type="text/css" href="http
# ...

# %%
payload = {'q': '동아일보'}
r = requests.get('https://www.google.com/search', params=payload)
print(r.text)
# Out:
# <!doctype html><html lang="ko"><head><meta charset="UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>&#46041;&#50500;&#51068;&#48372; - Google &#44160;&#49353;</title><script nonce="x2XwPMTRyZFLIV7gvQvsHg">(function(){
# ...

# %%
payload = {
    'method' : 'getLottoNumber',
    'drwtNo' : 1126,
}

r = requests.get('https://www.dhlottery.co.kr/common.do?method=getLottoNumber&drwNo=1126', params=payload)
#print(r.json())
#print(type(r.json()))

lotto_dict = r.json()
(f'이번주 당첨번호 :',print(lotto_dict['drwtNo1'], lotto_dict['drwtNo2'], lotto_dict['drwtNo3'], lotto_dict['drwtNo4'], lotto_dict['drwtNo5'], lotto_dict['drwtNo6']))
print(lotto_dict['drwtNo1'], lotto_dict['drwtNo2'], lotto_dict['drwtNo3'], lotto_dict['drwtNo4'], lotto_dict['drwtNo5'], lotto_dict['drwtNo6'])
#딕셔너리 형식
#A = {
#    '' : '',
#    '' : '',
#}
# Out:
# 4 5 9 11 37 40
# 4 5 9 11 37 40

# %%
이번주 당첨번호 : [], BN : 7
{'1회차': [],
 '2회차': [],
 '3회차': [],
 '4회차': [],
 '5회차': [],}

꽝
5등! 5천원
꽝
5등! 5천원
꽝
# Out:
#   Cell In[714], line 1
#     이번주 당첨번호 : [], BN : 7
#         ^
# SyntaxError: invalid syntax

# %%
payload = {
    'method' : 'getLottoNumber',
    'drwtNo' : 1126,
}

r = requests.get('https://www.dhlottery.co.kr/common.do?method=getLottoNumber&drwNo=1126', params=payload)


lotto_dict = r.json()
#print(f"[{lotto_dict['drwtNo1']}, {lotto_dict['drwtNo2']}, {lotto_dict['drwtNo3']}, {lotto_dict['drwtNo4']}, {lotto_dict['drwtNo5']}, {lotto_dict['drwtNo6']}]")
a = [lotto_dict['drwtNo1'], lotto_dict['drwtNo2'], lotto_dict['drwtNo3'], lotto_dict['drwtNo4'], lotto_dict['drwtNo5'], lotto_dict['drwtNo6']]
print(a)

numbers = list(range(1,46))
b = random.sample(numbers,6)
print(b)

if a == b:
    print('당첨')
else:
    print('꽝')

# a = 리스트 형태 , []
# Out:
# [4, 5, 9, 11, 37, 40]
# [35, 26, 31, 5, 30, 2]
# 꽝

# %%
\
# Out:
#   Cell In[1026], line 1
#     \
#      ^
# SyntaxError: incomplete input

# %%
print(f"'0회차': [{random.sample(numbers), random.sample(numbers), random.sample(numbers), random.sample(numbers), random.sample(numbers), random.sample(numbers)}]")
# Out:
# -------------------------------------------------
# TypeError       Traceback (most recent call last)
# Cell In[1027], line 1
# ----> 1 print(f"'0회차': [{random.sample(numbers), random.sample(numbers), random.sample(numbers), random.sample(numbers), random.sample(numbers), random.sample(numbers)}]")
#
# TypeError: Random.sample() missing 1 required positional argument: 'k'
